# %%
# %pip install ultralytics==8.0.196

from IPython import display
display.clear_output() # 모든 출력을 지웁니다.

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.75 🚀 Python-3.13.2 torch-2.6.0 CPU (Apple M4 Pro)
# Setup complete ✅ (12 CPUs, 48.0 GB RAM, 79.4/926.4 GB disk)

# %%
from ultralytics import YOLO

# YOLOv8n(가벼운 버전) 로드
model = YOLO("best.pt")

# 모델 정보 출력
model.info()
# Out:
# Model summary: 129 layers, 11,136,374 parameters, 0 gradients, 28.6 GFLOPs
# (129, 11136374, 0, 28.6491136)

# %%
import cv2
import matplotlib.pyplot as plt

# 객체 탐지 수행
results = model("27.png")

# 탐지된 이미지 가져오기
img = results[0].plot()  # Bounding Box 그리기

# Matplotlib으로 출력
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# image 1/1 /Users/songbeom/final-project/farm-web-python/src/models/27.png: 640x480 23 immature_strawberrys, 2 ripe_strawberrys, 42.0ms
# Speed: 1.7ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
